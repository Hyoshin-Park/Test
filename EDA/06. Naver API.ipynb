# %% [markdown]
# # 06. Naver API

# %% [markdown]
# - 네이버 개발자 센터
# - https://developers.naver.com/apps/#/myapps/ZqRszmrRZrQTIiQ0Li8f/overview
# - Application
#     - 애플리케이션 등록
#     - 애플리케이션 이름 ds_study
#     - 사용 API
#         - 검색
#         - 데이터랩(검색어트렌드)
#         - 데이터랩(쇼핑인사이트)
#         - Clova Face Recognition
#     - 환경추가
#         - WEB 설정
#         -  http://localhost
#     - Client ID: ZqRszmrRZrQTIiQ0Li8f
#     - Client Secret: DTtsXQIykd

# %% [markdown]
# ## 2. 네이버 검색 API 사용하기

# %% [markdown]
# - https://developers.naver.com/docs/serviceapi/search/blog/blog.md#%EB%B8%94%EB%A1%9C%EA%B7%B8 # 개발 가이드

# %% [markdown]
# - urllib:  http 프로토콜에 따라서 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request: 클라이언트의 요청을 처리하는 모듈
# - urllib.parse: url 주소에 대한 분석

# %% [markdown]
# ### 검색 블로그

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:10:12 +0900",
# "total": 283311,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>학원 배우는 환경이 중요",
# "link": "https:\/\/blog.naver.com\/sennie?Redirect=Log&logNo=222660401833",
# "description": "저는 요즘 <b>파이썬</b>학원에 다니면서 코딩 공부를 하고 있는데요. 요즘은 초등학생뿐만 아니라, 중... 중고등학생들은 <b>파이썬</b>이나 C언어 등을 학교에서 배운다고 해요. 필수 교과 과정으로 채택이 된 만큼, 저도... ",
# "bloggername": "통통쎄니의 신나는 하루!",
# "bloggerlink": "https://blog.naver.com/sennie",
# "postdate": "20220228"
#
# },
# {
# "title": "<b>파이썬</b>학원 수월한 프로그래밍 입문과정",
# "link": "https:\/\/blog.naver.com\/yellow4028?Redirect=Log&logNo=222650859782",
# "description": "<b>파이썬</b>학원 수월한 프로그래밍 입문과정 인생을 이렇게 살아도 괜찮을까? 의문이 들 정도로 저는... 그래서 어떤 걸 배워볼까 곰곰이 고민해보다가 <b>파이썬</b>이라는 프로그래밍 언어를 알게 되었죠. 프로그래밍... ",
# "bloggername": "운동하는 엄마",
# "bloggerlink": "https://blog.naver.com/yellow4028",
# "postdate": "20220218"
#
# },
# {
# "title": "<b>파이썬</b>학원 필수적인 심화절차",
# "link": "https:\/\/blog.naver.com\/dorothy2648?Redirect=Log&logNo=222579385478",
# "description": "제 주변만 하더라도 체계적으로 배우고 싶어서 <b>파이썬</b>학원을 알아보는 선배들도 많았어요. 저 역시도... 이미 구직했다고 하더라도 자기 계발을 위해서 <b>파이썬</b>학원을 선택하는 케이스도 많았고, 저처럼 미래를... ",
# "bloggername": "오즈미니",
# "bloggerlink": "https://blog.naver.com/dorothy2648",
# "postdate": "20211126"
#
# },
# {
# "title": "<b>파이썬</b>학원 꼼꼼히 배우자!",
# "link": "https:\/\/blog.naver.com\/whitelovejin?Redirect=Log&logNo=222613630070",
# "description": "작년 <b>파이썬</b>학원에 다니면서, 많은 것을 배울 수 있어서 정말 유익한 시간을 보냈습니다! 제가 처음 배우는 언어로 <b>파이썬</b>을 선택한 이유는, 일단 다른 언어에 비해서 배우기 쉽다는 점과 제가 원했던 데이터... ",
# "bloggername": "소소한 일상",
# "bloggerlink": "https://blog.naver.com/whitelovejin",
# "postdate": "20220105"
#
# },
# {
# "title": "<b>파이썬</b> 설치, 환경 변수, No module named 'PIL' 오류",
# "link": "https:\/\/blog.naver.com\/logix200?Redirect=Log&logNo=222653547191",
# "description": "오늘은 <b>파이썬</b> 설치 방법과 그 후에 발생할 수 있는 몇 가지 문제를 해결하는 방법에 대한 정보를 공유하고자 합니다. 1. <b>파이썬</b> 설치 방법 아시다시피 Python은 컴퓨터 개발자를 위한 프로그래밍... ",
# "bloggername": "IT 트랜스미터 옥희돌이",
# "bloggerlink": "https://blog.naver.com/logix200",
# "postdate": "20220221"
#
# },
# {
# "title": "코딩테스트 <b>파이썬</b> 공부 사이트 추천  IT 대기업 합격 꿀팁",
# "link": "https:\/\/blog.naver.com\/kut_da_92?Redirect=Log&logNo=222639956316",
# "description": "어떤 언어로 시험을 볼지 정하기 저는 <b>파이썬</b>을 선택해 시험을 준비했습니다 <b>파이썬</b>을 추천드리는 이유는 4가지 인데요. 1) 문법이 쉬워 사용하기 수월 하다 2) 문자열/리스트 등을 처리하는 부분이 편리... ",
# "bloggername": "은택's 유랑기",
# "bloggerlink": "https://blog.naver.com/kut_da_92",
# "postdate": "20220206"
#
# },
# {
# "title": "<b>파이썬</b> 프로그래밍 코딩 개발 환경 Visual Studio Code로... ",
# "link": "https:\/\/blog.naver.com\/skdaksdptn?Redirect=Log&logNo=222620667531",
# "description": "프로그래밍 언어 중에서 <b>파이썬</b>(Python)이 대세다. 문법이 굉장히 쉽다. 다양한 인터프리터 언어... 이렇다 보니 개발자라면 &quot;Life is too short, You need python.&quot;, 인생은 짧으니 <b>파이썬</b> 코딩을 통해 개발... ",
# "bloggername": "짜루의 이것저것 리뷰",
# "bloggerlink": "https://blog.naver.com/skdaksdptn",
# "postdate": "20220113"
#
# },
# {
# "title": "<b>파이썬</b> 코딩 : 기본부터 프로젝트까지 (초보자 필독)",
# "link": "https:\/\/blog.naver.com\/urmyver?Redirect=Log&logNo=222662973879",
# "description": "#<b>파이썬</b> 코딩 스마트폰이나 컴퓨터 및 각종 기계가 동작하기 위해서 반드시 필요로 하는 소프트웨어는... 이번 포스팅에선 코딩을 처음 입문하는 대부분의 사람들이 가장 먼저 공부하는 <b>파이썬</b> 코딩에 대한... ",
# "bloggername": "주들의 그리 대단하진 않지만 굉장한 이야기",
# "bloggerlink": "https://blog.naver.com/urmyver",
# "postdate": "20220303"
#
# },
# {
# "title": "<b>파이썬</b>학원 다양한 경험을 쌓기!",
# "link": "https:\/\/blog.naver.com\/sya415?Redirect=Log&logNo=222577544403",
# "description": "아무래도 장래도 밝고 수요도 많을 것 같다는 생각이 들어서 이직해야겠다는 마음을 가지고 <b>파이썬</b>학원... 결국에 커리큘럼이 마음에 들어서 한 <b>파이썬</b>학원 방문하게 됐는데요. 처음에 멘토 선생님께서... ",
# "bloggername": "재미있게 즐겁게",
# "bloggerlink": "https://blog.naver.com/sya415",
# "postdate": "20211124"
#
# },
# {
# "title": "전주<b>파이썬</b> - 마이크로비트로 <b>파이썬</b>을 학습해요 1",
# "link": "https:\/\/blog.naver.com\/stupid1714?Redirect=Log&logNo=222612435309",
# "description": "전주 <b>파이썬</b> 학원 스마트라이프연구학원이예요 <b>파이썬</b>의 가독성은 코딩언어로 선택하는 가장 좋은 조건이라고 말씀하시는 분들이 많아요 이유는 쉽고, 복잡한 문법일 아니라 시간을 낭비하지 않을 수... ",
# "bloggername": "전주코딩 교육 전문 스마트라이프연구소 & 학원",
# "bloggerlink": "https://blog.naver.com/stupid1714",
# "postdate": "20220104"
#
# }
# ]
# }

# %%
response.status
# Out:
# 200

# %%
# 글자로 읽을 경우, decode utf-8 설정
print(response_body.decode("utf-8"))
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:10:12 +0900",
# "total": 283311,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>학원 배우는 환경이 중요",
# "link": "https:\/\/blog.naver.com\/sennie?Redirect=Log&logNo=222660401833",
# "description": "저는 요즘 <b>파이썬</b>학원에 다니면서 코딩 공부를 하고 있는데요. 요즘은 초등학생뿐만 아니라, 중... 중고등학생들은 <b>파이썬</b>이나 C언어 등을 학교에서 배운다고 해요. 필수 교과 과정으로 채택이 된 만큼, 저도... ",
# "bloggername": "통통쎄니의 신나는 하루!",
# "bloggerlink": "https://blog.naver.com/sennie",
# "postdate": "20220228"
#
# },
# {
# "title": "<b>파이썬</b>학원 수월한 프로그래밍 입문과정",
# "link": "https:\/\/blog.naver.com\/yellow4028?Redirect=Log&logNo=222650859782",
# "description": "<b>파이썬</b>학원 수월한 프로그래밍 입문과정 인생을 이렇게 살아도 괜찮을까? 의문이 들 정도로 저는... 그래서 어떤 걸 배워볼까 곰곰이 고민해보다가 <b>파이썬</b>이라는 프로그래밍 언어를 알게 되었죠. 프로그래밍... ",
# "bloggername": "운동하는 엄마",
# "bloggerlink": "https://blog.naver.com/yellow4028",
# "postdate": "20220218"
#
# },
# {
# "title": "<b>파이썬</b>학원 필수적인 심화절차",
# "link": "https:\/\/blog.naver.com\/dorothy2648?Redirect=Log&logNo=222579385478",
# "description": "제 주변만 하더라도 체계적으로 배우고 싶어서 <b>파이썬</b>학원을 알아보는 선배들도 많았어요. 저 역시도... 이미 구직했다고 하더라도 자기 계발을 위해서 <b>파이썬</b>학원을 선택하는 케이스도 많았고, 저처럼 미래를... ",
# "bloggername": "오즈미니",
# "bloggerlink": "https://blog.naver.com/dorothy2648",
# "postdate": "20211126"
#
# },
# {
# "title": "<b>파이썬</b>학원 꼼꼼히 배우자!",
# "link": "https:\/\/blog.naver.com\/whitelovejin?Redirect=Log&logNo=222613630070",
# "description": "작년 <b>파이썬</b>학원에 다니면서, 많은 것을 배울 수 있어서 정말 유익한 시간을 보냈습니다! 제가 처음 배우는 언어로 <b>파이썬</b>을 선택한 이유는, 일단 다른 언어에 비해서 배우기 쉽다는 점과 제가 원했던 데이터... ",
# "bloggername": "소소한 일상",
# "bloggerlink": "https://blog.naver.com/whitelovejin",
# "postdate": "20220105"
#
# },
# {
# "title": "<b>파이썬</b> 설치, 환경 변수, No module named 'PIL' 오류",
# "link": "https:\/\/blog.naver.com\/logix200?Redirect=Log&logNo=222653547191",
# "description": "오늘은 <b>파이썬</b> 설치 방법과 그 후에 발생할 수 있는 몇 가지 문제를 해결하는 방법에 대한 정보를 공유하고자 합니다. 1. <b>파이썬</b> 설치 방법 아시다시피 Python은 컴퓨터 개발자를 위한 프로그래밍... ",
# "bloggername": "IT 트랜스미터 옥희돌이",
# "bloggerlink": "https://blog.naver.com/logix200",
# "postdate": "20220221"
#
# },
# {
# "title": "코딩테스트 <b>파이썬</b> 공부 사이트 추천  IT 대기업 합격 꿀팁",
# "link": "https:\/\/blog.naver.com\/kut_da_92?Redirect=Log&logNo=222639956316",
# "description": "어떤 언어로 시험을 볼지 정하기 저는 <b>파이썬</b>을 선택해 시험을 준비했습니다 <b>파이썬</b>을 추천드리는 이유는 4가지 인데요. 1) 문법이 쉬워 사용하기 수월 하다 2) 문자열/리스트 등을 처리하는 부분이 편리... ",
# "bloggername": "은택's 유랑기",
# "bloggerlink": "https://blog.naver.com/kut_da_92",
# "postdate": "20220206"
#
# },
# {
# "title": "<b>파이썬</b> 프로그래밍 코딩 개발 환경 Visual Studio Code로... ",
# "link": "https:\/\/blog.naver.com\/skdaksdptn?Redirect=Log&logNo=222620667531",
# "description": "프로그래밍 언어 중에서 <b>파이썬</b>(Python)이 대세다. 문법이 굉장히 쉽다. 다양한 인터프리터 언어... 이렇다 보니 개발자라면 &quot;Life is too short, You need python.&quot;, 인생은 짧으니 <b>파이썬</b> 코딩을 통해 개발... ",
# "bloggername": "짜루의 이것저것 리뷰",
# "bloggerlink": "https://blog.naver.com/skdaksdptn",
# "postdate": "20220113"
#
# },
# {
# "title": "<b>파이썬</b> 코딩 : 기본부터 프로젝트까지 (초보자 필독)",
# "link": "https:\/\/blog.naver.com\/urmyver?Redirect=Log&logNo=222662973879",
# "description": "#<b>파이썬</b> 코딩 스마트폰이나 컴퓨터 및 각종 기계가 동작하기 위해서 반드시 필요로 하는 소프트웨어는... 이번 포스팅에선 코딩을 처음 입문하는 대부분의 사람들이 가장 먼저 공부하는 <b>파이썬</b> 코딩에 대한... ",
# "bloggername": "주들의 그리 대단하진 않지만 굉장한 이야기",
# "bloggerlink": "https://blog.naver.com/urmyver",
# "postdate": "20220303"
#
# },
# {
# "title": "<b>파이썬</b>학원 다양한 경험을 쌓기!",
# "link": "https:\/\/blog.naver.com\/sya415?Redirect=Log&logNo=222577544403",
# "description": "아무래도 장래도 밝고 수요도 많을 것 같다는 생각이 들어서 이직해야겠다는 마음을 가지고 <b>파이썬</b>학원... 결국에 커리큘럼이 마음에 들어서 한 <b>파이썬</b>학원 방문하게 됐는데요. 처음에 멘토 선생님께서... ",
# "bloggername": "재미있게 즐겁게",
# "bloggerlink": "https://blog.naver.com/sya415",
# "postdate": "20211124"
#
# },
# {
# "title": "전주<b>파이썬</b> - 마이크로비트로 <b>파이썬</b>을 학습해요 1",
# "link": "https:\/\/blog.naver.com\/stupid1714?Redirect=Log&logNo=222612435309",
# "description": "전주 <b>파이썬</b> 학원 스마트라이프연구학원이예요 <b>파이썬</b>의 가독성은 코딩언어로 선택하는 가장 좋은 조건이라고 말씀하시는 분들이 많아요 이유는 쉽고, 복잡한 문법일 아니라 시간을 낭비하지 않을 수... ",
# "bloggername": "전주코딩 교육 전문 스마트라이프연구소 & 학원",
# "bloggerlink": "https://blog.naver.com/stupid1714",
# "postdate": "20220104"
#
# }
# ]
# }

# %% [markdown]
# ### 책 검색

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:12:34 +0900",
# "total": 1519,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "이것이 취업을 위한 코딩 테스트다 with <b>파이썬</b> (취업과 이직을 결정하는 알고리즘 인터뷰 완벽 가이드)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16439154",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/391/16439154.jpg?type=m1&udate=20200928",
# "author": "나동빈",
# "price": "34000",
# "discount": "30600",
# "publisher": "한빛미디어",
# "pubdate": "20200805",
# "isbn": "1162243074 9791162243077",
# "description": "8가지 핵심 알고리즘 이론을 쉽게 설명하고, 관련 실전 문제를 풀이했다. 출제 유형 분석, 이론 설명, 기출문제 풀이까지! 어떤 코딩 테스트도 이 책 한 권으로 대비할 수 있을 것이다. 코딩 테스트에서 주로 선택하는 <b>파이썬</b>을 기반으로 설명되어 있으며, <b>파이썬</b> 코드 외에도 C/C++, 자바 코드를 추가로 제공한다."
#
# },
# {
# "title": "Do it! 점프 투 <b>파이썬</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15052904",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20200910",
# "author": "박응용",
# "price": "18800",
# "discount": "16900",
# "publisher": "이지스퍼블리싱",
# "pubdate": "20190620",
# "isbn": "1163030910 9791163030911",
# "description": "<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "
#
# },
# {
# "title": "혼자 공부하는 <b>파이썬</b> (<b>파이썬</b> 최신 버전 반영)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=15028688",
# "image": "https://bookthumb-phinf.pstatic.net/cover/150/286/15028688.jpg?type=m1&udate=20220129",
# "author": "윤인성",
# "price": "18000",
# "discount": "16200",
# "publisher": "한빛미디어",
# "pubdate": "20190610",
# "isbn": "1162241888 9791162241882",
# "description": "1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서(<b>파이썬</b> 최신 버전 반영)\n27명의 베타리더 검증으로, ‘함께 만든’ 입문자 맞춤형 도서\n\n이 책은 독학으로 프로그래밍 언어를 처음 배우려는 입문자가, 혹은 <b>파이썬</b>을 배우려는 입문자가 ‘꼭 필요한 내용을 제대로’ 학습할 수 있도록 구성했다. ‘무엇을’... "
#
# },
# {
# "title": "<b>파이썬</b> 알고리즘 인터뷰 (95가지 알고리즘 문제 풀이로 완성하는 코딩 테스트)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16406247",
# "image": "https://bookthumb-phinf.pstatic.net/cover/164/062/16406247.jpg?type=m1&udate=20220301",
# "author": "박상길",
# "price": "38000",
# "discount": "34200",
# "publisher": "책만",
# "pubdate": "20200715",
# "isbn": "1189909170 9791189909178",
# "description": "물론, <b>파이썬</b>으로 구현하는 코드 풀이를 통해 성능 최적화 기법, <b>파이썬</b>의 핵심 문법과 다양한 실용 테크닉까지 배울 수 있는, 초보 개발자와 숙련 개발자... 이 책은 현업과 실무에 유용한 주요 알고리즘 이론을 깊숙이 이해하고, <b>파이썬</b>의 핵심 기능과 문법까지 상세하게 이해할 수 있는 취업용 코딩 테스트를... "
#
# },
# {
# "title": "<b>파이썬</b>으로 배우는 공업수학",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=22017877",
# "image": "https://bookthumb-phinf.pstatic.net/cover/220/178/22017877.jpg?type=m1&udate=20220301",
# "author": "김도영|김재현|김현태|정보현|정순모",
# "price": "30000",
# "discount": "27000",
# "publisher": "지오북스",
# "pubdate": "20220301",
# "isbn": "1191346285 9791191346282",
# "description": "이 책은 주어진 공학문제를 해결하기 위하여, 단순화시키기, 수식을 이용하여 모형 만들기, 수학적 해 찾기, PYTHON 등의 소프트웨어로 해 찾기, 해의 실제적 의미 찾기 등 네 단계를 강조하고 있다. 이 과정을 통하여 학생들은 공학인증제(ABEEK) 등에서 요구하는 문제 해결 능력을 기를 수 있다.책의 구성은 1학년... "
#
# },
# {
# "title": "<b>파이썬</b> for Beginner (쉽고 빠르게 익히는 프로그래밍의 기본 원리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21371083",
# "image": "https://bookthumb-phinf.pstatic.net/cover/213/710/21371083.jpg?type=m1&udate=20211223",
# "author": "우재남",
# "price": "25000",
# "discount": "24250",
# "publisher": "한빛아카데미",
# "pubdate": "20220103",
# "isbn": "1156645743 9791156645740",
# "description": "일단 따라하면 바로 이해되는 <b>파이썬</b> 프로그래밍<b>파이썬</b>을 처음 접하는 독자를 대상으로 일대일 수업처럼 자세히 설명한 책입니다.꼭 알아야 할 핵심... 일단 코드를 입력하고 실행하다 보면 어느새 <b>파이썬</b> 프로그래밍과 친숙해져 있을 것입니다!※ 본 도서는 대학 강의용 교재로 개발되었으므로 연습문제 해답은... "
#
# },
# {
# "title": "<b>파이썬</b> 머신러닝 완벽 가이드 (다양한 캐글 예제와 함께 기초 알고리즘부터 최신 기법까지 배우는)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16238302",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/383/16238302.jpg?type=m1&udate=20200423",
# "author": "권철민",
# "price": "38000",
# "discount": "34200",
# "publisher": "위키북스",
# "pubdate": "20200207",
# "isbn": "1158391927 9791158391928",
# "description": "자세한 이론 설명과 <b>파이썬</b> 실습을 통해 머신러닝을 완벽하게 배울 수 있습니다!《<b>파이썬</b> 머신러닝 완벽 가이드》는 이론 위주의 머신러닝 책에서 탈피해 다양한 실전 예제를 직접 구현해 보면서 머신러닝을 체득할 수 있도록 만들었습니다.  캐글과 UCI 머신러닝 리포지토리에서 난이도가 있는 실습... "
#
# },
# {
# "title": "<b>파이썬</b>을 이용한 비트코인 자동매매",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18214660",
# "image": "https://bookthumb-phinf.pstatic.net/cover/182/146/18214660.jpg?type=m1&udate=20210316",
# "author": "유대표|조대표",
# "price": "27000",
# "discount": "24300",
# "publisher": "파이스탁",
# "pubdate": "20210322",
# "isbn": "1196608814 9791196608811",
# "description": "이 책은 최근 인기 있는 프로그래밍 언어인 <b>파이썬</b>을 사용하여 국내 3대 거래소(코빗, 빗썸, 업비트)... 프로그래밍 경험이 없는 일반인을 대상으로 <b>파이썬</b> 기초 문법부터 시작하여 24시간 실시간 자동... 있어 <b>파이썬</b>을 처음 배우는 분들이 유익하고 재미있게 프로그래밍을 배울 수 있도록 합니다. 책에서... "
#
# },
# {
# "title": "쉽게 따라 만드는 <b>파이썬</b> 주식 자동매매 시스템 (증권사 API 사용, 매매전략 구현, 실전 투자 전환까지!)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=21119890",
# "image": "https://bookthumb-phinf.pstatic.net/cover/211/198/21119890.jpg?type=m1&udate=20211207",
# "author": "박준성",
# "price": "28000",
# "discount": "25200",
# "publisher": "길벗",
# "pubdate": "20211014",
# "isbn": "1165217163 9791165217167",
# "description": "개발 환경 구축부터 실전 투자 전환까지\n<b>파이썬</b>으로 나만의 주식 자동매매 시스템을 만든다!\n\n이 책은 <b>파이썬</b>을 이용하여 주식 자동매매 시스템을 만드는... 개발 환경을 구축하고, 프로젝트를 만드는 데 필요한 기초 <b>파이썬</b> 문법은 물론 증권 데이터를 주고받기 위해 키움증권 API를 사용하는 방법과 웹... "
#
# },
# {
# "title": "<b>파이썬</b> 증권 데이터 분석 (<b>파이썬</b> 입문, 웹 스크레이핑, 트레이딩 전략, 자동 매매)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16381920",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/819/16381920.jpg?type=m1&udate=20201117",
# "author": "김황후",
# "price": "32000",
# "discount": "28800",
# "publisher": "한빛미디어",
# "pubdate": "20200701",
# "isbn": "1162243201 9791162243206",
# "description": "투자 기법과 프로그래밍 기술로 &#x0D;자신만의 퀀트 투자 시스템을 완성하라&#x0D;&#x0D;『<b>파이썬</b> 증권 데이터 분석』은 웹 스크레이핑으로 증권 데이터를 주기적으로 자동 수집, 분석, 자동 매매, 예측하는 전 과정을 <b>파이썬</b>으로 직접 구현한다. 그 과정에서 금융 데이터 처리 기본 라이브러리(팬더스)부터 주가... "
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 영화

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:14:02 +0900",
# "total": 1,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "<b>파이썬</b> 앤 가드",
# "link": "https://movie.naver.com/movie/bi/mi/basic.nhn?code=152070",
# "image": "https://ssl.pstatic.net/imgmovie/mdi/mit110/1520/152070_P01_145336.jpg",
# "subtitle": "PYTHON AND GUARD",
# "pubDate": "2015",
# "director": "안톤 디아코프|",
# "actor": "",
# "userRating": "0.00"
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 카페(cafearticle)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:14:12 +0900",
# "total": 132494,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> 생노배 입문자 질문",
# "link": "http://cafe.naver.com/as6060/1389758",
# "description": "&lt;백신 후기글 외 코로나/백신/자가격리 관련 글 금지&gt; 안녕하세요 이번에 필수교양으로 컴프밍을 배우게됐는데 일주일에 두시간은 <b>파이썬</b>으로 문제풀고 실습하고 하더라구요 제가 프로그래밍에 관하여 문외한이고 <b>파이썬</b>... ",
# "cafename": "맨체스터 유나이티드 - The Red Devil...",
# "cafeurl": "https://cafe.naver.com/as6060"
#
# },
# {
# "title": "고등 정보과목에서 <b>파이썬</b> 질문이에요",
# "link": "http://cafe.naver.com/mathall/2364640",
# "description": "1학년 과목 중 정보과목에 <b>파이썬</b>이 있길레 컴퓨터는 전혀 무지한 아이라 집근처 컴퓨터학원에서 C언어를 배우고있어요. 컴퓨터학원 선생님은 c언어를 배우면 <b>파이썬</b>이 쉽다고하는데 지금 굳이 c언어를 배우는게... ",
# "cafename": "[상위1%카페] 대한민국 상위1% 교육정...",
# "cafeurl": "https://cafe.naver.com/mathall"
#
# },
# {
# "title": "<b>파이썬</b>데이터 시험 정리 및 응시료 할인 내용",
# "link": "http://cafe.naver.com/dokchi/11505787",
# "description": "<b>파이썬</b>데이터 시험 정리 및 응시료 할인 내용 최근 <b>파이썬</b>데이터 에 대한 관심이 집중되면서 관련 교육이나 자격증 취득을 희망하는 분들이 늘어나고 있는거 같습니다. 파이써는 프로그래밍을 비전공자들에게... ",
# "cafename": "독취사-취업,대학생,대기업,공기업,GS...",
# "cafeurl": "https://cafe.naver.com/dokchi"
#
# },
# {
# "title": "C언어 ,<b>파이썬</b>",
# "link": "http://cafe.naver.com/dieselmania/37342471",
# "description": "독학을 하려고 하는데요 ㅋㅋㅋ 씨언어를 배우는게 나중 활용도가 좋다고해서요 ㅠㅠ 독학책 추천할만한거ㅜ있나요? 아님 걍 <b>파이썬</b> 바우도 될까요?",
# "cafename": "●디젤매니아● 대한민국 일등 패션 커...",
# "cafeurl": "https://cafe.naver.com/dieselmania"
#
# },
# {
# "title": "<b>파이썬</b>이요, 관심많은 초5되는 남아 가능한가요?",
# "link": "http://cafe.naver.com/malltail/6357557",
# "description": "수업 가능할까요? 관심있어 하는데 스크래치코딩? 앤트리 경험없구요. <b>파이썬</b>에 수학적인 부분때문에 중등부터 추천한다는 글은 봤는데 아이는 중등 2전까지 수학 실력이구요. 초고학년 아이 <b>파이썬</b> 보내는분 계실까요?",
# "cafename": "● 몰테일 스토리 - 쉽고 빠른 해외직...",
# "cafeurl": "https://cafe.naver.com/malltail"
#
# },
# {
# "title": "<b>파이썬</b> 잘하시는 분 훈수 좀 부탁드립니다",
# "link": "http://cafe.naver.com/steamindiegame/4808387",
# "description": "제가 독학할 당시에 시간 가는줄도 모르고 막 해서 저거 했을 때 대충 몇시간 걸렸는지도 모르고.....ㅠ 동아리에 1학년 2학년 섞여있는데 <b>파이썬</b>을 아예 안 해본 애들도 있고 능숙하게 할 줄 아는 애들도 있어서.. 참... ",
# "cafename": "왁물원 :: 종합 거시기 스트리머 우왁...",
# "cafeurl": "https://cafe.naver.com/steamindiegame"
#
# },
# {
# "title": "<b>파이썬</b> 정체기..",
# "link": "http://cafe.naver.com/sqlpd/28808",
# "description": "슬슬 취업을 겨냥한 공부를 해야할 시기가 되는듯 하여 <b>파이썬</b>&amp;자바를 집중적으로 공부하고 있는데 여느 강좌&amp;책을 봐도 대부분 <b>파이썬</b>의 기초부터 시작하고 실무에서 쓰일만한? 테스트 될만한? 그런 자료들이... ",
# "cafename": "데이터 전문가 포럼 (빅데이터분석기사...",
# "cafeurl": "https://cafe.naver.com/sqlpd"
#
# },
# {
# "title": "<b>파이썬</b> 배우시는 분 계신가요???",
# "link": "http://cafe.naver.com/gumecpm/49968",
# "description": "수학이 싫어 문과를 도망치듯 갔었는데 일하면서 부딫히는 모든 일들이 수학과 관련이 있고 이과와 관련이 있네요...ㅋㅋㅋㅋ 그래도 나름 즐기면서 일하고 있는데 <b>파이썬</b>에 자꾸 관심이 가네요.! 잘 아시는 선배님들 조언... ",
# "cafename": "구매전문가",
# "cafeurl": "https://cafe.naver.com/gumecpm"
#
# },
# {
# "title": "VEX 실력 늘리는데 <b>파이썬</b>이나 다른 컴퓨터언어 공부하는게 도움이 되나용??",
# "link": "http://cafe.naver.com/sidefx/9836",
# "description": "<b>파이썬</b>이나 C언어 같은 다른 컴퓨터 언어들은 체계적인 인강이 널렸던데, 다른언어 공부하는게 VEX 고수되는데 도움이 될까요?? <b>파이썬</b> 알면 장점은 후디니에서 나중에 HDA같은거 만들때 도움된다고는 알고... ",
# "cafename": "대한민국 후디니 아티스트 커뮤니티 \"...",
# "cafeurl": "https://cafe.naver.com/sidefx"
#
# },
# {
# "title": "R, <b>파이썬</b> 공부가 YT에 도움 될까요?",
# "link": "http://cafe.naver.com/anyhelpst/16147",
# "description": "아이디어를 구현하는 데 기간이 꽤 걸리구요. 교육신청을 하면 시간을 꽤 뺏기는 편이라 도움이 될지 고민입니다 R 이나 <b>파이썬</b>을 수강할 교육기회가 있는데 이런 것들을 배우면 YT 전략 짜는 데 도움이 될까요?",
# "cafename": "애니헬프 시스템트레이딩 (자동매매 트...",
# "cafeurl": "https://cafe.naver.com/anyhelpst"
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 쇼핑(shop)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:14:20 +0900",
# "total": 262689,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "으뜸 <b>파이썬</b> 책 박동규,강영민 생능출판",
# "link": "https://search.shopping.naver.com/gate.nhn?id=31177641381",
# "image": "https://shopping-phinf.pstatic.net/main_3117764/31177641381.20220306004725.jpg",
# "lprice": "28800",
# "hprice": "",
# "mallName": "네이버",
# "productId": "31177641381",
# "productType": "1",
# "brand": "",
# "maker": "생능출판",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "난생처음 <b>파이썬</b> 프로그래밍/ 한빛아카데미",
# "link": "https://search.shopping.naver.com/gate.nhn?id=31110109114",
# "image": "https://shopping-phinf.pstatic.net/main_3111010/31110109114.20220301012358.jpg",
# "lprice": "22800",
# "hprice": "",
# "mallName": "네이버",
# "productId": "31110109114",
# "productType": "1",
# "brand": "",
# "maker": "한빛아카데미",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "혼자 공부하는 <b>파이썬</b> / 프로그래밍 언어 독학 책 교재",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82065283309",
# "image": "https://shopping-phinf.pstatic.net/main_8206528/82065283309.jpg",
# "lprice": "16200",
# "hprice": "",
# "mallName": "북초이스",
# "productId": "82065283309",
# "productType": "2",
# "brand": "윤인성",
# "maker": "한빛미디어",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "컴퓨팅 기반 문제해결 with <b>파이썬</b> 인티티피북스",
# "link": "https://search.shopping.naver.com/gate.nhn?id=31165663462",
# "image": "https://shopping-phinf.pstatic.net/main_3116566/31165663462.20220305023540.jpg",
# "lprice": "18000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "31165663462",
# "productType": "1",
# "brand": "",
# "maker": "인피니티북스",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "한빛아카데미 데이터 과학을 위한 <b>파이썬</b> 프로그래밍",
# "link": "https://search.shopping.naver.com/gate.nhn?id=30967489089",
# "image": "https://shopping-phinf.pstatic.net/main_3096748/30967489089.20220217032357.jpg",
# "lprice": "25000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "30967489089",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "파워 유저를 위한 <b>파이썬</b> EXPRESS",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82808311871",
# "image": "https://shopping-phinf.pstatic.net/main_8280831/82808311871.jpg",
# "lprice": "30000",
# "hprice": "",
# "mallName": "daoncp",
# "productId": "82808311871",
# "productType": "2",
# "brand": "",
# "maker": "생능출판",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "한빛아카데미 난생처음 컴퓨팅 사고 with <b>파이썬</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=31177432178",
# "image": "https://shopping-phinf.pstatic.net/main_3117743/31177432178.20220305233029.jpg",
# "lprice": "21850",
# "hprice": "",
# "mallName": "네이버",
# "productId": "31177432178",
# "productType": "1",
# "brand": "",
# "maker": "한빛아카데미",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "한빛아카데미 <b>파이썬</b> 자료구조와 알고리즘 for beginner",
# "link": "https://search.shopping.naver.com/gate.nhn?id=30995931305",
# "image": "https://shopping-phinf.pstatic.net/main_3099593/30995931305.20220218225456.jpg",
# "lprice": "23580",
# "hprice": "",
# "mallName": "네이버",
# "productId": "30995931305",
# "productType": "1",
# "brand": "",
# "maker": "한빛아카데미",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "머신 러닝 교과서 with <b>파이썬</b> 사이킷런 텐서플로",
# "link": "https://search.shopping.naver.com/gate.nhn?id=30996168006",
# "image": "https://shopping-phinf.pstatic.net/main_3099616/30996168006.20220219001426.jpg",
# "lprice": "29700",
# "hprice": "",
# "mallName": "네이버",
# "productId": "30996168006",
# "productType": "1",
# "brand": "",
# "maker": "길벗",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# },
# {
# "title": "<b>파이썬</b> for Beginner(3판) / 한빛아카데미(책 도서)",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83701615611",
# "image": "https://shopping-phinf.pstatic.net/main_8370161/83701615611.jpg",
# "lprice": "25000",
# "hprice": "",
# "mallName": "마루서재",
# "productId": "83701615611",
# "productType": "2",
# "brand": "",
# "maker": "한빛아카데미",
# "category1": "도서",
# "category2": "컴퓨터/IT",
# "category3": "프로그래밍 언어",
# "category4": ""
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 백과 사전(encyc)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:14:33 +0900",
# "total": 446,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.naver?docId=3580815&cid=59088&categoryId=59096",
# "description": "‘<b>파이썬</b>’이다. 간결한 문법으로 입문자가 이해하기 쉽고, 다양한 분야에 활용할 수 있기 때문이다. 이 외에도 <b>파이썬</b>은 머신러닝, 그래픽, 웹 개발 등 여러 업계에서 선호하는 언어로 꾸준히... ",
# "thumbnail": "http://openapi-dbscthumb.phinf.naver.net/4749_000_1/20170118193349632_0CHSSS5Y6.png/01_16.png?type=m160_160"
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.naver?docId=3607513&cid=58598&categoryId=59316",
# "description": " 컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어.  <b>파이썬</b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에는... ",
# "thumbnail": "http://openapi-dbscthumb.phinf.naver.net/4751_000_3/20170710213206672_OPHLG2VOW.jpg/992_170575_10034.jpg?type=m160_160"
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.naver?docId=3533295&cid=40942&categoryId=32838",
# "description": " 오픈소스 고급 프로그래밍 언어 중 하나이다.  C언어를 기반으로 한 오픈소스 고급 프로그래밍 언어로, 1991년 귀도 반 로섬(Guido van Rossum)에 의해 설계 및 개발되었다. <b>파이썬</b>이라는 이름은 <b>파이썬</b>을... ",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "<b>파이썬</b> ( 영어: Python )은 1991년 네덜란드계 프로그래머인 귀도 반 로섬이 발표한 고급 프로그래밍 언어로, 플랫폼에 독립적이며 인터프리터식, 객체지향적, 동적 타이핑(dynamically typed) 대화형... ",
# "thumbnail": ""
#
# },
# {
# "title": "C<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/C%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "C<b>파이썬</b> (CPython)은 <b>파이썬</b> 프로그래밍 언어의 참조 구현체이다. C와 <b>파이썬</b>으로 작성된 C<b>파이썬</b>은 이 언어에 가장 널리 사용되는 기본 구현체이다. C<b>파이썬</b>은 인터프리트 과정 이전에 <b>파이썬</b> 코드를... ",
# "thumbnail": ""
#
# },
# {
# "title": "바이오<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "바이오<b>파이썬</b> (Biopython) 프로젝트는 분자생물학 계산에 자유롭게 사용하기 위한 <b>파이썬</b> 라이브러리 구축 프로젝트이다. 같이 보기 바이오자바 바이오펄 외부 링크 biopython.org",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b>의 역사",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%98_%EC%97%AD%EC%82%AC",
# "description": "프로그래밍 언어 <b>파이썬</b>은 1980년대 말에 구상되었으며 그 구현체는 1989년 12월 예외 처리가 가능하고 아메바 운영 체제와 통신이 가능한 ABC의 후속 프로그래밍 언어로서 CWI(Centrum Wiskunde... ",
# "thumbnail": ""
#
# },
# {
# "title": "아나콘다 (<b>파이썬</b> 배포판)",
# "link": "https://ko.wikipedia.org/wiki/%EC%95%84%EB%82%98%EC%BD%98%EB%8B%A4_(%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B0%B0%ED%8F%AC%ED%8C%90)",
# "description": "아나콘다 (Anaconda)는 패키지 관리와 디플로이를 단순케 할 목적으로 과학 계산(데이터 과학, 기계 학습 애플리케이션, 대규모 데이터 처리, 예측 분석 등)을 위한 <b>파이썬</b>과 R 프로그래밍 언어의 자유... ",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b> 소프트웨어 재단",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4_%EC%9E%AC%EB%8B%A8",
# "description": "<b>파이썬</b> 소프트웨어 재단 (Python Software Foundation, PSF)은 <b>파이썬</b> 프로그래밍 언어에 헌신하는 비영리 단체로서, 2001년 3월 6일 런칭했다. 이 단체의 임무는 <b>파이썬</b> 공동체의 개발을 발전시키고... ",
# "thumbnail": ""
#
# },
# {
# "title": "자이썬",
# "link": "https://ko.wikipedia.org/wiki/%EC%9E%90%EC%9D%B4%EC%8D%AC",
# "description": "자이썬 ( Jython )은 <b>파이썬</b>의 자바 구현으로, Jim Hugunin에 의해 처음으로 만들어졌다. 처음에는 <b>파이썬</b> 표준 구현의 이름(CPython)을 따라 JPython 라는 이름을 썼다. 자이썬은 자바 언어로만 작성되었기... ",
# "thumbnail": ""
#
# }
# ]
# }

# %% [markdown]
# ## 3. 상품 검색
# - "몰스킨"

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "ZqRszmrRZrQTIiQ0Li8f"
client_secret = "DTtsXQIykd"
encText = urllib.parse.quote("몰스킨")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 08 Mar 2022 12:30:01 +0900",
# "total": 29568,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24014924801",
# "image": "https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg",
# "lprice": "18770",
# "hprice": "",
# "mallName": "네이버",
# "productId": "24014924801",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "노트/수첩",
# "category4": "노트"
#
# },
# {
# "title": "<b>몰스킨</b> <b>몰스킨</b> 무료각인 룰드 노트 익스팬디드 소프트 라지 -블랙",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29051050229",
# "image": "https://shopping-phinf.pstatic.net/main_2905105/29051050229.20211001010311.jpg",
# "lprice": "14750",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29051050229",
# "productType": "1",
# "brand": "",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "노트/수첩",
# "category4": "노트"
#
# },
# {
# "title": "헤지스 남성 가먼트워싱 <b>몰스킨</b> 셋업 캐주얼자켓 차콜 HZJA1D401CG",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29165079857",
# "image": "https://shopping-phinf.pstatic.net/main_2916507/29165079857.20211009051017.jpg",
# "lprice": "237710",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29165079857",
# "productType": "1",
# "brand": "헤지스",
# "maker": "LF",
# "category1": "패션의류",
# "category2": "남성의류",
# "category3": "재킷",
# "category4": ""
#
# },
# {
# "title": "<b>몰스킨</b> 2022년 먼슬리 다이어리 하드 포켓",
# "link": "https://search.shopping.naver.com/gate.nhn?id=30298725968",
# "image": "https://shopping-phinf.pstatic.net/main_3029872/30298725968.20211226021048.jpg",
# "lprice": "23590",
# "hprice": "",
# "mallName": "네이버",
# "productId": "30298725968",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "브렌우드 코오롱 솔리드 <b>몰스킨</b> 자켓 BRJCA21311BUX",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28533382599",
# "image": "https://shopping-phinf.pstatic.net/main_2853338/28533382599.20211004011347.jpg",
# "lprice": "132990",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28533382599",
# "productType": "1",
# "brand": "브렌우드",
# "maker": "코오롱인더스트리",
# "category1": "패션의류",
# "category2": "남성의류",
# "category3": "재킷",
# "category4": ""
#
# },
# {
# "title": "르몽생미셸 지니언 워크자켓 블루 <b>몰스킨</b> 프렌치 워크자켓",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83453383930",
# "image": "https://shopping-phinf.pstatic.net/main_8345338/83453383930.jpg",
# "lprice": "332000",
# "hprice": "",
# "mallName": "스프링스트릿 마켓",
# "productId": "83453383930",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "패션의류",
# "category2": "남성의류",
# "category3": "재킷",
# "category4": ""
#
# },
# {
# "title": "[<b>몰스킨</b>] 2022 데일리 다이어리 라지 4종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=30590941102",
# "image": "https://shopping-phinf.pstatic.net/main_3059094/30590941102.jpg",
# "lprice": "38500",
# "hprice": "",
# "mallName": "마켓컬리",
# "productId": "30590941102",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> 2022 위클리 12개월 다이어리 소프트커버 포켓 (4색상)",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83373780374",
# "image": "https://shopping-phinf.pstatic.net/main_8337378/83373780374.jpg",
# "lprice": "21700",
# "hprice": "",
# "mallName": "몰스킨스토어",
# "productId": "83373780374",
# "productType": "2",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "로가디스 경량 <b>몰스킨</b> 재킷 RY0911P40A",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24544505137",
# "image": "https://shopping-phinf.pstatic.net/main_2454450/24544505137.20201021213203.jpg",
# "lprice": "87640",
# "hprice": "",
# "mallName": "네이버",
# "productId": "24544505137",
# "productType": "1",
# "brand": "로가디스",
# "maker": "삼성물산",
# "category1": "패션의류",
# "category2": "남성의류",
# "category3": "재킷",
# "category4": ""
#
# },
# {
# "title": "21FW 라이크라 <b>몰스킨</b> 팬츠 3종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28831203586",
# "image": "https://shopping-phinf.pstatic.net/main_2883120/28831203586.20220103015940.jpg",
# "lprice": "42360",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28831203586",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "패션의류",
# "category2": "남성의류",
# "category3": "바지",
# "category4": ""
#
# }
# ]
# }

# %% [markdown]
# ## (1) gen search url

# %% [markdown]
# - encText = urllib.parse.quote("몰스킨")
# - url = "https://openapi.naver.com/v1/search/shop?query=" +

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = "/" + api_node + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text) 
    param_start = "&start=" + str(start_num)
    param_disp = "&display=" + str(disp_num)

    return base + node + param_query + param_start + param_disp

# %%
gen_search_url("shop", "Test", 10, 3)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?queryTest&start10&disp3'

# %% [markdown]
# ## (2) get_result_onpage

# %%
import json
import datetime

# %%
def get_result_onpage(url):
    client_id = "ZqRszmrRZrQTIiQ0Li8f"
    client_secret = "DTtsXQIykd"
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    print("[%s] Url Request Success" % datetime.datetime.now())
    return json.loads(response.read().decode("utf-8"))

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 3, 8, 12, 37, 37, 983509)

# %%
url = gen_search_url("shop", "몰스킨", 1, 5)
one_result = get_result_onpage(url)
# Out:
# [2022-03-08 12:41:47.491245] Url Request Success

# %%
one_result
# Out:
# {'lastBuildDate': 'Tue, 08 Mar 2022 12:41:47 +0900',
#  'total': 29564,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24014924801',
#    'image': 'https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg',
#    'lprice': '18770',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '24014924801',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '<b>몰스킨</b> <b>몰스킨</b> 무료각인 룰드 노트 익스팬디드 소프트 라지 -블랙',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=29051050229',
#    'image': 'https://shopping-phinf.pstatic.net/main_2905105/29051050229.20211001010311.jpg',
#    'lprice': '14750',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '29051050229',
#    'productType': '1',
#    'brand': '',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '헤지스 남성 가먼트워싱 <b>몰스킨</b> 셋업 캐주얼자켓 차콜 HZJA1D401CG',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=29165079857',
#    'image': 'https://shopping-phinf.pstatic.net/main_2916507/29165079857.20211009051017.jpg',
#    'lprice': '237710',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '29165079857',
#    'productType': '1',
#    'brand': '헤지스',
#    'maker': 'LF',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '재킷',
#    'category4': ''},
#   {'title': '<b>몰스킨</b> 2022년 먼슬리 다이어리 하드 포켓',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=30298725968',
#    'image': 'https://shopping-phinf.pstatic.net/main_3029872/30298725968.20211226021048.jpg',
#    'lprice': '23590',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '30298725968',
#    'productType': '1',
#    'brand': '',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '브렌우드 코오롱 솔리드 <b>몰스킨</b> 자켓 BRJCA21311BUX',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=28533382599',
#    'image': 'https://shopping-phinf.pstatic.net/main_2853338/28533382599.20211004011347.jpg',
#    'lprice': '132990',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '28533382599',
#    'productType': '1',
#    'brand': '브렌우드',
#    'maker': '코오롱인더스트리',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '재킷',
#    'category4': ''},
#   {'title': '르몽생미셸 지니언 워크자켓 블루 <b>몰스킨</b> 프렌치 워크자켓',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=83453383930',
#    'image': 'https://shopping-phinf.pstatic.net/main_8345338/83453383930.jpg',
#    'lprice': '332000',
#    'hprice': '',
#    'mallName': '스프링스트릿 마켓',
#    'productId': '83453383930',
#    'productType': '2',
#    'brand': '',
#    'maker': '',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '재킷',
#    'category4': ''},
#   {'title': '[<b>몰스킨</b>] 2022 데일리 다이어리 라지 4종',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=30590941102',
#    'image': 'https://shopping-phinf.pstatic.net/main_3059094/30590941102.jpg',
#    'lprice': '38500',
#    'hprice': '',
#    'mallName': '마켓컬리',
#    'productId': '30590941102',
#    'productType': '2',
#    'brand': '',
#    'maker': '',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 2022 위클리 12개월 다이어리 소프트커버 포켓 (4색상)',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=83373780374',
#    'image': 'https://shopping-phinf.pstatic.net/main_8337378/83373780374.jpg',
#    'lprice': '21700',
#    'hprice': '',
#    'mallName': '몰스킨스토어',
#    'productId': '83373780374',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '로가디스 경량 <b>몰스킨</b> 재킷 RY0911P40A',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24544505137',
#    'image': 'https://shopping-phinf.pstatic.net/main_2454450/24544505137.20201021213203.jpg',
#    'lprice': '87640',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '24544505137',
#    'productType': '1',
#    'brand': '로가디스',
#    'maker': '삼성물산',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '재킷',
#    'category4': ''},
#   {'title': '21FW 라이크라 <b>몰스킨</b> 팬츠 3종',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=28831203586',
#    'image': 'https://shopping-phinf.pstatic.net/main_2883120/28831203586.20220103015940.jpg',
#    'lprice': '42360',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '28831203586',
#    'productType': '1',
#    'brand': '',
#    'maker': '',
#    'category1': '패션의류',
#    'category2': '남성의류',
#    'category3': '바지',
#    'category4': ''}]}

# %%
one_result["items"][0]["title"]
# Out:
# '<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린'

# %%
one_result["items"][0]["link"]
# Out:
# 'https://search.shopping.naver.com/gate.nhn?id=24014924801'

# %%
one_result["items"][0]["lprice"]
# Out:
# '18770'

# %%
one_result["items"][0]["mallName"]
# Out:
# '네이버'

# %% [markdown]
# ## (3) get_fields()

# %%
one_result["items"][0]
# Out:
# {'title': '<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린',
#  'link': 'https://search.shopping.naver.com/gate.nhn?id=24014924801',
#  'image': 'https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg',
#  'lprice': '18770',
#  'hprice': '',
#  'mallName': '네이버',
#  'productId': '24014924801',
#  'productType': '1',
#  'brand': '몰스킨',
#  'maker': '몰스킨',
#  'category1': '생활/건강',
#  'category2': '문구/사무용품',
#  'category3': '노트/수첩',
#  'category4': '노트'}

# %%
import pandas as pd

def get_fields(json_data):
    title = [each["title"]for each in json_data["items"]]
    link = [each["link"]for each in json_data["items"]]
    lprice = [each["lprice"]for each in json_data["items"]]
    mall_name = [each["mallName"]for each in json_data["items"]]

    result_pd = pd.DataFrame({
        "title": title,
        "link": link,
        "lprice": lprice,
        "mall": mall_name,

    },columns=["title", "lprice", "link", "mall"])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                                title  lprice  \
# 0                 <b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린   18770
# 1  <b>몰스킨</b> <b>몰스킨</b> 무료각인 룰드 노트 익스팬디드 소프트 라지 -블랙   14750
# 2    헤지스 남성 가먼트워싱 <b>몰스킨</b> 셋업 캐주얼자켓 차콜 HZJA1D401CG  237710
# 3                    <b>몰스킨</b> 2022년 먼슬리 다이어리 하드 포켓   23590
# 4           브렌우드 코오롱 솔리드 <b>몰스킨</b> 자켓 BRJCA21311BUX  132990
# 5              르몽생미셸 지니언 워크자켓 블루 <b>몰스킨</b> 프렌치 워크자켓  332000
# 6                   [<b>몰스킨</b>] 2022 데일리 다이어리 라지 4종   38500
# 7       <b>몰스킨</b> 2022 위클리 12개월 다이어리 소프트커버 포켓 (4색상)   21700
# 8                   로가디스 경량 <b>몰스킨</b> 재킷 RY0911P40A   87640
# 9                         21FW 라이크라 <b>몰스킨</b> 팬츠 3종   42360
#
#                                                 link       mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 5  https://search.shopping.naver.com/gate.nhn?id=...  스프링스트릿 마켓
# 6  https://search.shopping.naver.com/gate.nhn?id=...       마켓컬리
# 7  https://search.shopping.naver.com/gate.nhn?id=...     몰스킨스토어
# 8  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 9  https://search.shopping.naver.com/gate.nhn?id=...        네이버

# %% [markdown]
# ## (4) delete_tag()

# %%
def delete_tag(input_str):
    input_str = input_str.replace("<b>", "")
    input_str = input_str.replace("</b>", "")
    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each["title"])for each in json_data["items"]]
    link = [each["link"]for each in json_data["items"]]
    lprice = [each["lprice"]for each in json_data["items"]]
    mall_name = [each["mallName"]for each in json_data["items"]]

    result_pd = pd.DataFrame({
        "title": title,
        "link": link,
        "lprice": lprice,
        "mall": mall_name,

    },columns=["title", "lprice", "link", "mall"])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                       title  lprice  \
# 0               몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린   18770
# 1       몰스킨 몰스킨 무료각인 룰드 노트 익스팬디드 소프트 라지 -블랙   14750
# 2  헤지스 남성 가먼트워싱 몰스킨 셋업 캐주얼자켓 차콜 HZJA1D401CG  237710
# 3                  몰스킨 2022년 먼슬리 다이어리 하드 포켓   23590
# 4         브렌우드 코오롱 솔리드 몰스킨 자켓 BRJCA21311BUX  132990
# 5            르몽생미셸 지니언 워크자켓 블루 몰스킨 프렌치 워크자켓  332000
# 6                 [몰스킨] 2022 데일리 다이어리 라지 4종   38500
# 7     몰스킨 2022 위클리 12개월 다이어리 소프트커버 포켓 (4색상)   21700
# 8                 로가디스 경량 몰스킨 재킷 RY0911P40A   87640
# 9                       21FW 라이크라 몰스킨 팬츠 3종   42360
#
#                                                 link       mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 3  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 5  https://search.shopping.naver.com/gate.nhn?id=...  스프링스트릿 마켓
# 6  https://search.shopping.naver.com/gate.nhn?id=...       마켓컬리
# 7  https://search.shopping.naver.com/gate.nhn?id=...     몰스킨스토어
# 8  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 9  https://search.shopping.naver.com/gate.nhn?id=...        네이버

# %%
url = gen_search_url("shop", "몰스킨", 1, 5)
json_result = get_result_onpage(url)
pd_result = get_fields(json_result)
# Out:
# [2022-03-08 14:23:19.534780] Url Request Success

# %%
pd_result
# Out:
#                                       title  lprice  \
# 0               몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린   18770
# 1       몰스킨 몰스킨 무료각인 룰드 노트 익스팬디드 소프트 라지 -블랙   14750
# 2            르몽생미셸 지니언 워크자켓 블루 몰스킨 프렌치 워크자켓  332000
# 3  헤지스 남성 가먼트워싱 몰스킨 셋업 캐주얼자켓 차콜 HZJA1D401CG  237710
# 4                  몰스킨 2022년 먼슬리 다이어리 하드 포켓   23590
#
#                                                 link       mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  스프링스트릿 마켓
# 3  https://search.shopping.naver.com/gate.nhn?id=...        네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...        네이버

# %% [markdown]
# ## (5) actMain()

# %%
result_mol = []

for n in range(1, 1000, 100):
    url = gen_search_url("shop", "몰스킨", n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)

    result_mol.append(pd_result)

result_mol = pd.concat(result_mol)
# Out:
# [2022-03-08 14:25:18.442736] Url Request Success
# [2022-03-08 14:25:18.701846] Url Request Success
# [2022-03-08 14:25:18.943598] Url Request Success
# [2022-03-08 14:25:19.206765] Url Request Success
# [2022-03-08 14:25:19.485087] Url Request Success
# [2022-03-08 14:25:19.737671] Url Request Success
# [2022-03-08 14:25:20.028935] Url Request Success
# [2022-03-08 14:25:20.293074] Url Request Success
# [2022-03-08 14:25:20.562670] Url Request Success
# [2022-03-08 14:25:20.823073] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
result_mol.reset_index(drop=True, inplace=True)

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol.tail()
# Out:
#                                                  title  lprice  \
# 995                           몰스킨 무료각인 스퀘어드 엑스라지 -크래프트   23950
# 996                                 몰스킨 19아스달 연대기 룰드 L   39600
# 997                        몰스킨 T 백팩 컬렉션-테크니컬 위브 타이드 그린  216900
# 998  몰스킨 Moleskine PRO Notebook Soft Cover 7.5 x 9....   52990
# 999  몰스킨 Moleskine Classic Notebook Soft Cover 8.5 ...   55170
#
#                                                   link mall
# 995  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 996  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 997  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 998  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 999  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
result_mol["lprice"] = result_mol["lprice"].astype("float")
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## (5) to_excel()

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      -------------------------------------- 150.0/150.0 KB 8.7 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
writer = pd.ExcelWriter("../data/06_molskin_diary_in_naver_shop.xlsx", engine="xlsxwriter")
result_mol.to_excel(writer, sheet_name="Sheet1")

workbook = writer.book
worksheet = writer.sheets["Sheet1"]
worksheet.set_column("A:A", 4)
worksheet.set_column("B:B", 60)
worksheet.set_column("C:C", 10)
worksheet.set_column("D:D", 10)
worksheet.set_column("E:E", 50)
worksheet.set_column("F:F", 10)

worksheet.conditional_format("C2:C1001", {"type": "3_color_scale"})
writer.save()

# %%
one_result["items"][0]["link"]
# Out:
# 'https://search.shopping.naver.com/gate.nhn?id=24014924801'

# %%
import set_matplotlib_hangul
# Out:
# Hangul OK in your Windows!!!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15, 6))
sns.countplot(
    result_mol["mall"],
    data=result_mol,
    palette="RdYlGn",
    order=result_mol["mall"].value_counts().index,

)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\nihso\miniconda3\envs\ds_study\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
